# %%
# %%
# Install necessary libraries for Llama-Index and related embeddings and LLMs.
# %pip install llama-index
# %pip install llama-index-vector-stores-faiss
# %pip install -U sentence-transformers==2.2.2 
# %pip install llama-index-embeddings-huggingface
# %pip install llama-index-embeddings-instructor
# %pip install llama-index-llms-huggingface
# %pip install llama-index-llms-huggingface-api
# %pip install llama-index-embeddings-huggingface-api
# %pip install nest-asyncio
# Out:
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
# Requirement already satisfied: llama-index in /opt/anaconda3/lib/python3.9/site-packages (0.10.61)
# Requirement already satisfied: llama-index-agent-openai<0.3.0,>=0.1.4 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index) (0.2.9)
# Requirement already satisfied: llama-index-cli<0.2.0,>=0.1.2 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index) (0.1.13)
# Requirement already satisfied: llama-index-core==0.10.61 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index) (0.10.61)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.5 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index) (0.1.11)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index) (0.2.7)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index) (0.9.48)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.27 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index) (0.1.28)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index) (0.1.8)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.3 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index) (0.1.7)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.2 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index) (0.1.3)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.4 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index) (0.1.32)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.1.2 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.61->llama-index) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (3.10.1)
# Requirement already satisfied: dataclasses-json in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (2023.10.0)
# Requirement already satisfied: httpx in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (1.22.4)
# Requirement already satisfied: openai>=1.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (1.40.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (2.1.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (9.2.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core==0.10.61->llama-index) (1.14.1)
# Requirement already satisfied: llama-cloud>=0.0.11 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-indices-managed-llama-cloud>=0.2.0->llama-index) (0.0.12)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-readers-llama-parse>=0.1.2->llama-index) (0.4.9)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.61->llama-index) (4.0.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (2.3.1)
# Requirement already satisfied: pydantic>=1.10 in /opt/anaconda3/lib/python3.9/site-packages (from llama-cloud>=0.0.11->llama-index-indices-managed-llama-cloud>=0.2.0->llama-index) (2.8.2)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.61->llama-index) (3.7.1)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.61->llama-index) (2022.9.24)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.61->llama-index) (1.0.5)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.61->llama-index) (3.3)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core==0.10.61->llama-index) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core==0.10.61->llama-index) (0.14.0)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.61->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.61->llama-index) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.61->llama-index) (2022.7.9)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core==0.10.61->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core==0.10.61->llama-index) (0.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core==0.10.61->llama-index) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core==0.10.61->llama-index) (1.26.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.61->llama-index) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core==0.10.61->llama-index) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json->llama-index-core==0.10.61->llama-index) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core==0.10.61->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core==0.10.61->llama-index) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core==0.10.61->llama-index) (2024.1)
# Requirement already satisfied: exceptiongroup in /opt/anaconda3/lib/python3.9/site-packages (from anyio->httpx->llama-index-core==0.10.61->llama-index) (1.1.3)
# Requirement already satisfied: packaging>=17.0 in /opt/anaconda3/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core==0.10.61->llama-index) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from pydantic>=1.10->llama-cloud>=0.0.11->llama-index-indices-managed-llama-cloud>=0.2.0->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.9/site-packages (from pydantic>=1.10->llama-cloud>=0.0.11->llama-index-indices-managed-llama-cloud>=0.2.0->llama-index) (2.20.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core==0.10.61->llama-index) (1.16.0)
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
# Requirement already satisfied: llama-index-vector-stores-faiss in /opt/anaconda3/lib/python3.9/site-packages (0.1.2)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-vector-stores-faiss) (0.10.61)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (3.10.1)
# Requirement already satisfied: dataclasses-json in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (2023.10.0)
# Requirement already satisfied: httpx in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.22.4)
# Requirement already satisfied: openai>=1.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.40.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (2.1.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (9.2.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (0.9.0)
# Requirement already satisfied: wrapt in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (4.0.2)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (2022.7.9)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (2.8.2)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (2022.9.24)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.0.5)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (3.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.26.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (2024.1)
# Requirement already satisfied: exceptiongroup in /opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.1.3)
# Requirement already satisfied: packaging>=17.0 in /opt/anaconda3/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (23.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (2.20.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-vector-stores-faiss) (1.16.0)
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
# Collecting sentence-transformers==2.2.2
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers==2.2.2) (4.41.2)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers==2.2.2) (4.66.5)
# Requirement already satisfied: torch>=1.6.0 in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers==2.2.2) (2.2.2)
# Requirement already satisfied: torchvision in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers==2.2.2) (0.17.2)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers==2.2.2) (1.22.4)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers==2.2.2) (1.0.2)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers==2.2.2) (1.7.2)
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers==2.2.2) (3.8.1)
# Requirement already satisfied: sentencepiece in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers==2.2.2) (0.2.0)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers==2.2.2) (0.23.4)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (6.0.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (4.12.2)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (1.10.1)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->sentence-transformers==2.2.2) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (2022.7.9)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers==2.2.2) (0.4.3)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.9/site-packages (from nltk->sentence-transformers==2.2.2) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.9/site-packages (from nltk->sentence-transformers==2.2.2) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sentence-transformers==2.2.2) (2.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from torchvision->sentence-transformers==2.2.2) (9.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.6.0->sentence-transformers==2.2.2) (2.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers==2.2.2) (2022.9.24)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.9/site-packages (from sympy->torch>=1.6.0->sentence-transformers==2.2.2) (1.2.1)
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
# Installing collected packages: sentence-transformers
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 2.7.0
#     Uninstalling sentence-transformers-2.7.0:
#       Successfully uninstalled sentence-transformers-2.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-embeddings-huggingface 0.2.2 requires sentence-transformers>=2.6.1, but you have sentence-transformers 2.2.2 which is incompatible.
# Successfully installed sentence-transformers-2.2.2
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
# Requirement already satisfied: llama-index-embeddings-huggingface in /opt/anaconda3/lib/python3.9/site-packages (0.2.2)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.23.4)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-embeddings-huggingface) (0.10.61)
# Collecting sentence-transformers>=2.6.1 (from llama-index-embeddings-huggingface)
#   Using cached sentence_transformers-3.0.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.12.2)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.10.1)
# Requirement already satisfied: minijinja>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.0.30)
# Requirement already satisfied: dataclasses-json in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.8)
# Requirement already satisfied: httpx in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.22.4)
# Requirement already satisfied: openai>=1.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.40.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.1.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (9.2.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.14.1)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.41.2)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.2.2)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.0.2)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.9/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.7.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.0.2)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2022.7.9)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.8.2)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2022.9.24)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.0.5)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.26.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.1.1)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.10.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.1.2)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/lib/python3.9/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.4.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2024.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.2.0)
# Requirement already satisfied: exceptiongroup in /opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.1.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (2.20.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.9/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.2.1)
# Using cached sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
# Installing collected packages: sentence-transformers
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 2.2.2
#     Uninstalling sentence-transformers-2.2.2:
#       Successfully uninstalled sentence-transformers-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-embeddings-instructor 0.1.3 requires sentence-transformers<3.0.0,>=2.2.2, but you have sentence-transformers 3.0.1 which is incompatible.
# Successfully installed sentence-transformers-3.0.1
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
# Requirement already satisfied: llama-index-embeddings-instructor in /opt/anaconda3/lib/python3.9/site-packages (0.1.3)
# Requirement already satisfied: instructorembedding<2.0.0,>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-embeddings-instructor) (1.0.1)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-embeddings-instructor) (0.10.61)
# Collecting sentence-transformers<3.0.0,>=2.2.2 (from llama-index-embeddings-instructor)
#   Using cached sentence_transformers-2.7.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: torch<3.0.0,>=2.1.2 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-embeddings-instructor) (2.2.2)
# Requirement already satisfied: PyYAML>=6.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (3.10.1)
# Requirement already satisfied: dataclasses-json in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (2023.10.0)
# Requirement already satisfied: httpx in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (1.22.4)
# Requirement already satisfied: openai>=1.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (1.40.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (2.1.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (9.2.0)
# Requirement already satisfied: requests>=2.31.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (0.9.0)
# Requirement already satisfied: wrapt in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-instructor) (1.14.1)
# ...
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (2022.9.24)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (1.0.5)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (3.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (1.26.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (2024.1)
# Requirement already satisfied: exceptiongroup in /opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (1.1.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (2.20.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.41->llama-index-llms-huggingface-api) (1.16.0)
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
# Requirement already satisfied: llama-index-embeddings-huggingface-api in /opt/anaconda3/lib/python3.9/site-packages (0.1.1)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (0.23.4)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-embeddings-huggingface-api) (0.10.61)
# Requirement already satisfied: llama-index-utils-huggingface<0.2.0,>=0.1.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-embeddings-huggingface-api) (0.1.1)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (6.0.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (4.12.2)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (3.10.1)
# Requirement already satisfied: minijinja>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (2.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (2.0.30)
# Requirement already satisfied: dataclasses-json in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (1.0.8)
# Requirement already satisfied: httpx in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (0.27.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (3.8.1)
# Requirement already satisfied: numpy<2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (1.22.4)
# Requirement already satisfied: openai>=1.1.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (1.40.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (2.1.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (9.2.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (0.7.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (0.9.0)
# Requirement already satisfied: wrapt in /opt/anaconda3/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (1.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (1.8.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/anaconda3/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (4.0.2)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (2022.7.9)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (2.8.2)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (1.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (2022.9.24)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (1.0.5)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (3.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface-api) (1.26.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (0.4.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (3.20.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (2024.1)
# Requirement already satisfied: exceptiongroup in /opt/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (1.1.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (2.20.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-huggingface-api) (1.16.0)
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.9/site-packages (1.6.0)
# WARNING: Ignoring invalid distribution -orch (/opt/anaconda3/lib/python3.9/site-packages)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%
# Import logging module to configure logging settings.
import logging
import sys

# Set up basic logging configuration to output debug information to the console.
logging.basicConfig(stream=sys.stdout, level=logging.DEBUG)
logging.getLogger().addHandler(logging.StreamHandler(stream=sys.stdout))

# %%
# %%
# Define the data for indexing. These are titles of various AI and Machine Learning topics.
data = [
    'Introduction to Artificial Intelligence and Machine Learning',
    'Supervised Learning Algorithms: Linear Regression and Logistic Regression',
    'Unsupervised Learning: Clustering Algorithms - KMeans and DBSCAN',
    'Neural Networks and Deep Learning: Introduction to TensorFlow and Keras',
    'Natural Language Processing (NLP) Techniques: Tokenization and Word Embeddings',
    'Computer Vision and Image Processing: Convolutional Neural Networks (CNNs)',
    'Reinforcement Learning and Decision Making: Q-Learning and Markov Decision Processes',
    'Time Series Forecasting: ARIMA and Exponential Smoothing Methods',
    'Model Evaluation and Performance Metrics: ROC Curves and Confusion Matrices',
    'Feature Engineering and Data Preprocessing: Handling Missing Data and Outliers'
]

# %%
# %%
# Import HuggingFaceEmbedding for embedding generation using a specific Hugging Face model.
# from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")

# %%
from llama_index.embeddings.huggingface_api import HuggingFaceInferenceAPIEmbedding

remote_embed_api = HuggingFaceInferenceAPIEmbedding(
    model_name="BAAI/bge-small-en-v1.5"
)

# %%
# %%
# Set up the HuggingFaceLLM to load the phi-1_5 model for local inference. (Commented out as it's not executed)

"""
from llama_index.llms.huggingface import HuggingFaceLLM

llm = HuggingFaceLLM(
    model_name="microsoft/phi-1_5",
    tokenizer_name="microsoft/phi-1_5",
    max_new_tokens=100,
    generate_kwargs={"temperature": 0.7, "top_k": 50, "top_p": 0.95, "do_sample":True},
    device_map="auto",
)
"""
# Out:
# '\nfrom llama_index.llms.huggingface import HuggingFaceLLM\n\nllm = HuggingFaceLLM(\n    model_name="microsoft/phi-1_5",\n    tokenizer_name="microsoft/phi-1_5",\n    max_new_tokens=100,\n    generate_kwargs={"temperature": 0.7, "top_k": 50, "top_p": 0.95, "do_sample":True},\n    device_map="auto",\n)\n'

# %%
# %%
# Alternatively, set up the HuggingFaceInferenceAPI to use a remote model for inference.
from llama_index.llms.huggingface_api import HuggingFaceInferenceAPI

remote_llm_api = HuggingFaceInferenceAPI(
    model_name="HuggingFaceH4/zephyr-7b-alpha"
)

# %%
# %%
# Import necessary components for setting up and managing the Llama-Index with FAISS vector store.
from llama_index.core import (
    load_index_from_storage,
    VectorStoreIndex,
    StorageContext,
    Document,
    Settings,
)
from llama_index.vector_stores.faiss import FaissVectorStore
from IPython.display import Markdown, display

# Set the LLM and embedding model to use for the ServiceContext.
Settings.llm = remote_llm_api
Settings.embed_model = remote_embed_api

import faiss

# Configure FAISS vector store with the appropriate dimensions for embeddings.
d = 384
faiss_index = faiss.IndexFlatL2(d)

vector_store = FaissVectorStore(faiss_index=faiss_index)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# %%
# %%
# Create documents from the data and build the vector store index from these documents.
import nest_asyncio

nest_asyncio.apply()
documents = [Document(text=t) for t in data]
index = VectorStoreIndex.from_documents(documents, storage_context=storage_context)
# Out:
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Introduction to Artificial Intelligence and Mac...
# > Adding chunk: Introduction to Artificial Intelligence and Mac...
# > Adding chunk: Introduction to Artificial Intelligence and Mac...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Supervised Learning Algorithms: Linear Regressi...
# > Adding chunk: Supervised Learning Algorithms: Linear Regressi...
# > Adding chunk: Supervised Learning Algorithms: Linear Regressi...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Unsupervised Learning: Clustering Algorithms - ...
# > Adding chunk: Unsupervised Learning: Clustering Algorithms - ...
# > Adding chunk: Unsupervised Learning: Clustering Algorithms - ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Neural Networks and Deep Learning: Introduction...
# > Adding chunk: Neural Networks and Deep Learning: Introduction...
# > Adding chunk: Neural Networks and Deep Learning: Introduction...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Natural Language Processing (NLP) Techniques: T...
# > Adding chunk: Natural Language Processing (NLP) Techniques: T...
# > Adding chunk: Natural Language Processing (NLP) Techniques: T...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Computer Vision and Image Processing: Convoluti...
# > Adding chunk: Computer Vision and Image Processing: Convoluti...
# > Adding chunk: Computer Vision and Image Processing: Convoluti...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Reinforcement Learning and Decision Making: Q-L...
# > Adding chunk: Reinforcement Learning and Decision Making: Q-L...
# > Adding chunk: Reinforcement Learning and Decision Making: Q-L...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Time Series Forecasting: ARIMA and Exponential ...
# > Adding chunk: Time Series Forecasting: ARIMA and Exponential ...
# > Adding chunk: Time Series Forecasting: ARIMA and Exponential ...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Model Evaluation and Performance Metrics: ROC C...
# > Adding chunk: Model Evaluation and Performance Metrics: ROC C...
# > Adding chunk: Model Evaluation and Performance Metrics: ROC C...
# DEBUG:llama_index.core.node_parser.node_utils:> Adding chunk: Feature Engineering and Data Preprocessing: Han...
# > Adding chunk: Feature Engineering and Data Preprocessing: Han...
# > Adding chunk: Feature Engineering and Data Preprocessing: Han...
# DEBUG:asyncio:Using selector: KqueueSelector
# Using selector: KqueueSelector
# Using selector: KqueueSelector

# %%
# %%
# Save the created index to disk for later use.
index.storage_context.persist()
# Out:
# DEBUG:fsspec.local:open file: /Users/ishaansehgal/Documents/rag_demo/storage/docstore.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/docstore.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/docstore.json
# DEBUG:fsspec.local:open file: /Users/ishaansehgal/Documents/rag_demo/storage/index_store.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/index_store.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/index_store.json
# DEBUG:fsspec.local:open file: /Users/ishaansehgal/Documents/rag_demo/storage/graph_store.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/graph_store.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/graph_store.json
# DEBUG:fsspec.local:open file: /Users/ishaansehgal/Documents/rag_demo/storage/image__vector_store.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/image__vector_store.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/image__vector_store.json

# %%
# %%
# Load the index from disk to enable querying.
vector_store = FaissVectorStore.from_persist_dir("./storage")
storage_context = StorageContext.from_defaults(
    vector_store=vector_store, persist_dir="./storage"
)
index = load_index_from_storage(storage_context=storage_context)
# Out:
# INFO:root:Loading llama_index.vector_stores.faiss.base from ./storage/default__vector_store.json.
# Loading llama_index.vector_stores.faiss.base from ./storage/default__vector_store.json.
# Loading llama_index.vector_stores.faiss.base from ./storage/default__vector_store.json.
# DEBUG:llama_index.core.storage.kvstore.simple_kvstore:Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage/docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage/docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage/docstore.json.
# DEBUG:fsspec.local:open file: /Users/ishaansehgal/Documents/rag_demo/storage/docstore.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/docstore.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/docstore.json
# DEBUG:llama_index.core.storage.kvstore.simple_kvstore:Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage/index_store.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage/index_store.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from ./storage/index_store.json.
# DEBUG:fsspec.local:open file: /Users/ishaansehgal/Documents/rag_demo/storage/index_store.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/index_store.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/index_store.json
# DEBUG:llama_index.core.graph_stores.simple:Loading llama_index.core.graph_stores.simple from ./storage/graph_store.json.
# Loading llama_index.core.graph_stores.simple from ./storage/graph_store.json.
# Loading llama_index.core.graph_stores.simple from ./storage/graph_store.json.
# DEBUG:fsspec.local:open file: /Users/ishaansehgal/Documents/rag_demo/storage/graph_store.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/graph_store.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/graph_store.json
# DEBUG:fsspec.local:open file: /Users/ishaansehgal/Documents/rag_demo/storage/property_graph_store.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/property_graph_store.json
# open file: /Users/ishaansehgal/Documents/rag_demo/storage/property_graph_store.json
# INFO:llama_index.core.indices.loading:Loading all indices.
# Loading all indices.
# Loading all indices.

# %%
# %%
# Create a query engine from the loaded index and perform a query to retrieve relevant information.
query_engine = index.as_query_engine()
response = query_engine.query("Teach me about AI")
# Out:
# DEBUG:llama_index.core.indices.utils:> Top 2 nodes:
# > [Node 0] [Similarity score:             0.557331] Introduction to Artificial Intelligence and Machine Learning
# > [Node 6] [Similarity score:             0.65251] Reinforcement Learning and Decision Making: Q-Learning and Markov Decision Processes
# > Top 2 nodes:
# > [Node 0] [Similarity score:             0.557331] Introduction to Artificial Intelligence and Machine Learning
# > [Node 6] [Similarity score:             0.65251] Reinforcement Learning and Decision Making: Q-Learning and Markov Decision Processes
# > Top 2 nodes:
# > [Node 0] [Similarity score:             0.557331] Introduction to Artificial Intelligence and Machine Learning
# > [Node 6] [Similarity score:             0.65251] Reinforcement Learning and Decision Making: Q-Learning and Markov Decision Processes
# DEBUG:urllib3.connectionpool:https://api-inference.huggingface.co:443 "POST /models/HuggingFaceH4/zephyr-7b-alpha HTTP/1.1" 200 None
# https://api-inference.huggingface.co:443 "POST /models/HuggingFaceH4/zephyr-7b-alpha HTTP/1.1" 200 None
# https://api-inference.huggingface.co:443 "POST /models/HuggingFaceH4/zephyr-7b-alpha HTTP/1.1" 200 None

# %%
# %%
# Display the query response in Markdown format.
display(Markdown(f"<b>{response}</b>"))
# Out:
# <b>
#
# Artificial Intelligence (AI) is a branch of computer science that focuses on creating intelligent machines that can learn, reason, and make decisions like humans do. AI involves the use of algorithms and statistical models to enable computers to perform tasks that would normally require human intelligence, such as speech recognition, image processing, and decision-making.
#
# AI is a rapidly growing field that has the potential to transform many industries, including healthcare, finance, and transportation. In healthcare, AI is being used to develop personalized treatment plans for patients, while in finance, it is being used to predict stock prices and identify fraud. In transportation, AI is being used to develop self-driving cars that can navigate roads safely and efficiently.
#
# There are several types of AI, including:
#
# 1. Rule-based systems: These systems use a set of predefined rules to make decisions.
#
# 2. Neural networks: These systems are modeled after the human brain and can learn and make decisions based on patterns in data.
#
# 3. Bayesian networks: These systems use probability theory to make decisions based on uncertain data.
#
# 4. Reinforcement learning: This type of AI involves learning through trial and error, and is often used in decision</b>
